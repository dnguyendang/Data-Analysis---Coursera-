# %% [markdown]
# <center>
#     <img src="https://gitlab.com/ibm/skills-network/courses/placeholder101/-/raw/master/labs/module%201/images/IDSNlogo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # **Web Scraping Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# ## Objectives

# %% [markdown]
# After completing this lab you will be able to:

# %% [markdown]
# *   Download a webpage using requests module
# *   Scrape all links from a web page
# *   Scrape all image urls from a web page
# *   Scrape data from html tables

# %% [markdown]
# ## Scrape [www.ibm.com](http://www.ibm.com/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2021-01-01)

# %% [markdown]
# Import the required modules and functions

# %%
import html5lib
from bs4 import BeautifulSoup # this module helps in web scrapping.
import requests  # this module helps us to download a web page

# %% [markdown]
# Download the contents of the web page

# %%
url = "http://www.ibm.com"

# %%
# get the contents of the webpage in text format and store in a variable called data
data  = requests.get(url).text

# %% [markdown]
# Create a soup object using the class BeautifulSoup

# %%
soup = BeautifulSoup(data,"html5lib")  # create a soup object using the variable 'data'

# %% [markdown]
# Scrape all links

# %%
for link in soup.find_all('a'):  # in html anchor/link is represented by the tag <a>
    print(link.get('href'))
# Out:
# https://www.ibm.com/ru/ru
# https://www.ibm.com/sitemap/ru/ru
# https://newsroom.ibm.com/Update-on-our-actions-War-in-Ukraine?lnk=ushpv18nf1
# https://www.ibm.com/about/secure-your-business/?lnk=ruhpv18f1
# https://www.ibm.com/cloud/campaign/cloud-simplicity/?lnk=ruhpv18f2
# https://www.ibm.com/analytics/data-fabric/?lnk=ruhpv18f3
# https://www.ibm.com/cloud/aiops/?lnk=ruhpv18f4
# https://www.ibm.com/consulting/?lnk=ruhpv18f5
# /products/offers-and-discounts?lnk=hpv18t5
# https://www.ibm.com/products/db2-database?lnk=STW_RU_HPT_T1_BLK&psrc=NONE&pexp=DEF&lnk2=trial_Db2Database
# https://www.ibm.com/products/verify-access?lnk=STW_RU_HPT_T2_BLK&psrc=NONE&pexp=DEF&lnk2=trial_Verify
# https://www.ibm.com/cloud/cloud-pak-for-automation?lnk=STW_RU_HPT_T3_BLK&psrc=NONE&pexp=DEF&lnk2=trial_CloudPakAtm
# https://www.ibm.com/cloud/watson-assistant?lnk=STW_RU_HPT_T4_BLK&psrc=NONE&pexp=DEF&lnk2=trial_WatAssist
# https://developer.ibm.com/depmodels/cloud/?lnk=hpv18ct16
# https://developer.ibm.com/technologies/artificial-intelligence?lnk=hpv18ct19
# https://www.ibm.com/demos/?lnk=hpv18ct12
# https://developer.ibm.com/?lnk=hpv18ct9
# https://www.ibm.com/docs/en?lnk=hpv18ct14
# https://www.redbooks.ibm.com/?lnk=ushpv18ct10
# https://www.ibm.com/support/home/?lnk=hpv18ct11
# https://www.ibm.com/training/?lnk=hpv18ct15
# /cloud/hybrid?lnk=hpv18pt14
# /cloud/learn/public-cloud?lnk=hpv18ct1
# /watson?lnk=ushpv18pt17
# /garage?lnk=hpv18pt13
# /blockchain?lnk=hpv18pt4
# https://www.ibm.com/thought-leadership/institute-business-value/?lnk=hpv18pt12
# /analytics?lnk=hpv18pt1
# /security?lnk=hpv18pt9
# /financing?lnk=hpv18pt3
# https://www.ibm.com/quantum-computing?lnk=hpv18pt16
# /cloud/hybrid?lnk=hpv18ct20
# /cloud/learn/public-cloud?lnk=hpv18ct1
# /cloud/redhat?lnk=hpv18ct13
# /watson?lnk=hpv18ct3
# https://www.ibm.com/quantum-computing?lnk=hpv18ct18
# /cloud/learn/kubernetes?lnk=hpv18ct8
# /products/spss-statistics?lnk=ushpv18ct7
# /blockchain?lnk=hpv18ct1
# https://www.ibm.com/employment?lnk=hpv18ct2
# https://www.ibm.com/case-studies/coca-cola-european-partners/?lnk=hpv18cs1
# /case-studies/search?lnk=hpv18cs2
# #

# %% [markdown]
# Scrape  all images

# %%
for link in soup.find_all('img'):# in html image is represented by the tag <img>
    print(link.get('src'))
# Out:
# //1.cms.s81c.com/sites/default/files/2022-02-23/Secure_0%5B1%5D.jpg
# //1.cms.s81c.com/sites/default/files/2022-02-23/Simplify_0%5B1%5D.jpg
# //1.cms.s81c.com/sites/default/files/2022-02-23/Data%2520driven_0%5B1%5D_0.jpg
# //1.cms.s81c.com/sites/default/files/2022-02-23/Automate_0%5B1%5D.jpg
# //1.cms.s81c.com/sites/default/files/2022-02-23/Transform_0%5B1%5D.jpg
# //1.cms.s81c.com/sites/default/files/2021-09-20/Db2-on-Cloud-22239-700x420.png
# //1.cms.s81c.com/sites/default/files/2021-09-20/Security-Verify-Access-Trial-444x254.png
# //1.cms.s81c.com/sites/default/files/2021-09-20/Cloud-pak-for-automation-444x260.png
# //1.cms.s81c.com/sites/default/files/2021-09-20/Watson-Assistant-23212-700x420.png

# %% [markdown]
# ## Scrape data from html tables

# %%
#The below url contains a html table with data about colors and color codes.

# %%
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/datasets/HTMLColorCodes.html"

# %% [markdown]
# Before proceeding to scrape a web site, you need to examine the contents, and the way data is organized on the website. Open the above url in your browser and check how many rows and columns are there in the color table.

# %%
# get the contents of the webpage in text format and store in a variable called data
data  = requests.get(url).text

# %%
soup = BeautifulSoup(data,"html5lib")

# %%
#find a html table in the web page
table = soup.find('table') # in html table is represented by the tag <table>

# %%
#Get all rows from the table
for row in table.find_all('tr'): # in html table row is represented by the tag <tr>
    # Get all columns in each row.
    cols = row.find_all('td') # in html a column is represented by the tag <td>
    color_name = cols[2].getText() # store the value in column 3 as color_name
    color_code = cols[3].getText() # store the value in column 4 as color_code
    print("{}--->{}".format(color_name,color_code))
# Out:
# Color Name--->Hex Code#RRGGBB
# lightsalmon--->#FFA07A
# salmon--->#FA8072
# darksalmon--->#E9967A
# lightcoral--->#F08080
# coral--->#FF7F50
# tomato--->#FF6347
# orangered--->#FF4500
# gold--->#FFD700
# orange--->#FFA500
# darkorange--->#FF8C00
# lightyellow--->#FFFFE0
# lemonchiffon--->#FFFACD
# papayawhip--->#FFEFD5
# moccasin--->#FFE4B5
# peachpuff--->#FFDAB9
# palegoldenrod--->#EEE8AA
# khaki--->#F0E68C
# darkkhaki--->#BDB76B
# yellow--->#FFFF00
# lawngreen--->#7CFC00
# chartreuse--->#7FFF00
# limegreen--->#32CD32
# lime--->#00FF00
# forestgreen--->#228B22
# green--->#008000
# powderblue--->#B0E0E6
# lightblue--->#ADD8E6
# lightskyblue--->#87CEFA
# skyblue--->#87CEEB
# deepskyblue--->#00BFFF
# lightsteelblue--->#B0C4DE
# dodgerblue--->#1E90FF

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
# Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2021-01-01).
